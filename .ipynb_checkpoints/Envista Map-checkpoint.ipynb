# %% [markdown]
# # Envista Mapping App
# A data viasualization app to map the City of San Francisco's Envista Construction Projects using data from their Open Data portal.
#
# Two databases exist, which contain Envista projects:
# 1) Envista Projects for Utility Excavation and Paving
# API Endpoint: https://data.sfgov.org/resource/dsie-4zfb.json
#
# 2) Envista Projects for Paving
# API Endpoint: https://data.sfgov.org/resource/vad7-rtjc.json

# %% [markdown]
# Start by importing needed Python libraries:

# %%
# %matplotlib inline
import datetime
import requests
import json
import sqlite3 as lite
import pandas as pd
import seaborn as sns

# %% [markdown]
# Query the utility API and store response in a dictionary:

# %%
url_util = ('https://data.sfgov.org/resource/dsie-4zfb.json')
    
r_util = requests.get(url_util)
response_dict_util = json.loads(r_util.text)

# %% [markdown]
# Look at response dictionary:

# %%
response_dict_util
# Out:
# [{u':@computed_region_bh8s_q3mv': u'57',
#   u':@computed_region_fyvs_ahh9': u'17',
#   u':@computed_region_p5aj_wyqh': u'9',
#   u':@computed_region_rxqg_mtj9': u'1',
#   u':@computed_region_yftq_j783': u'13',
#   u'cnn': u'8455201',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'StreetScape',
#   u'duration': u'540',
#   u'end_date': u'2019-02-22T00:00:00.000',
#   u'facility_indicator': u'Streetscape-Landscaping',
#   u'facility_type': u'Land',
#   u'facility_type_description': u'Streetscape-Landscaping',
#   u'group_code': u'2532J',
#   u'latitude': u'37.8008450398367',
#   u'limits': u'GOUGH ST to OCTAVIA ST (1600 - 1698) -- NORTH --',
#   u'location': {u'coordinates': [-122.428656, 37.800845], u'type': u'Point'},
#   u'longitude': u'-122.428656209738',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0503_SS_6',
#   u'project_name_full': u'2532J - Lombard Street Pedestrian Improvements',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-08-31T00:00:00.000',
#   u'street_name': u'LOMBARD ST',
#   u'x': u'6004477.09597',
#   u'y': u'2119809.33857'},
#  {u':@computed_region_bh8s_q3mv': u'309',
#   u':@computed_region_fyvs_ahh9': u'39',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'20334000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Pre-Planning for Sewer R&R work FY18-19. Once projects are developed, locations will be moved to new JO',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'595',
#   u'end_date': u'2020-02-17T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'latitude': u'37.7165920060607',
#   u'limits': u'TIOGA AVE intersection',
#   u'location': {u'coordinates': [-122.405609, 37.716592], u'type': u'Point'},
#   u'longitude': u'-122.405609274964',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0028_SW_262',
#   u'project_name_full': u'_NA - Sewer RR_FY18-19 - Planning',
#   u'project_status': u'Committed',
#   u'start_date': u'2018-07-02T00:00:00.000',
#   u'street_name': u'RUTLAND ST',
#   u'x': u'6010509.80218',
#   u'y': u'2089001.06706'},
#  {u':@computed_region_bh8s_q3mv': u'29491',
#   u':@computed_region_fyvs_ahh9': u'35',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'3',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'23276000',
#   u'create_date': u'2016-02-10T19:40:00.000',
#   u'dpw_project_class': u'Gas',
#   u'duration': u'90',
#   u'end_date': u'2016-07-30T23:59:00.000',
#   u'facility_type': u'Gas',
#   u'latitude': u'37.742673097884',
#   u'limits': u'TARAVAL ST intersection',
#   u'location': {u'coordinates': [-122.484264, 37.742673], u'type': u'Point'},
#   u'longitude': u'-122.484263608164',
#   u'modify_date': u'2016-06-07T01:33:00.000',
#   u'owner': u'PG&E',
#   u'project_id': u'31217760',
#   u'project_name_full': u'Replace V8006',
#   u'project_status': u'Started',
#   u'start_date': u'2016-05-01T00:00:00.000',
#   u'street_name': u'27TH AVE',
#   u'x': u'5987965.3937',
#   u'y': u'2098968.32098'},
#  {u':@computed_region_bh8s_q3mv': u'29491',
#   u':@computed_region_fyvs_ahh9': u'40',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'4',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'22982000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'489',
#   u'end_date': u'2016-08-07T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2272J',
#   u'latitude': u'37.7490746167916',
#   u'limits': u'QUINTARA ST intersection',
#   u'location': {u'coordinates': [-122.466336, 37.749075], u'type': u'Point'},
#   u'longitude': u'-122.466336396997',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0272_SW_13',
#   u'project_name_full': u'2422J - West Portal Avenue and Quintara Street Sewer Replacement',
#   u'project_status': u'Started',
#   u'start_date': u'2015-04-06T00:00:00.000',
#   u'street_name': u'10TH AVE',
#   u'x': u'5993196.81375',
#   u'y': u'2101189.32149'},
#  {u':@computed_region_bh8s_q3mv': u'58',
#   u':@computed_region_fyvs_ahh9': u'1',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'7235000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'239',
#   u'end_date': u'2016-11-29T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2493J',
#   u'latitude': u'37.7231665169395',
#   u'limits': u'BANCROFT AVE to CARROLL AVE (2500 - 2599)',
#   u'location': {u'coordinates': [-122.389336, 37.723167], u'type': u'Point'},
#   u'longitude': u'-122.389336112063',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0160_PR_38',
#   u'project_name_full': u'2493J - Ingalls St and Industrial St Pavement Renovation',
#   u'project_status': u'Started',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2016-04-04T00:00:00.000',
#   u'street_name': u'INGALLS ST',
#   u'x': u'6015264.15124',
#   u'y': u'2091299.04641'},
#  {u':@computed_region_bh8s_q3mv': u'28861',
#   u':@computed_region_fyvs_ahh9': u'5',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'6',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'21491000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Curb Ramps',
#   u'duration': u'419',
#   u'end_date': u'2017-05-28T00:00:00.000',
#   u'facility_indicator': u'Sidewalk',
#   u'facility_subindicator': u'Curb Ramp - Disability Access',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Sidewalk / Curb Ramp - Disability Access',
#   u'group_code': u'2492J',
#   u'latitude': u'37.7092600411973',
#   u'limits': u'LOWELL ST intersection',
#   u'location': {u'coordinates': [-122.445205, 37.70926], u'type': u'Point'},
#   u'longitude': u'-122.445204591539',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0201_CR_1',
#   u'project_name_full': u'2492J - Various Locations Pavement Renovation No 20',
#   u'project_status': u'Started',
#   u'start_date': u'2016-04-04T00:00:00.000',
#   u'street_name': u'BYRON CT',
#   u'x': u'5999003.84663',
#   u'y': u'2086567.56115'},
#  {u':@computed_region_bh8s_q3mv': u'28861',
#   u':@computed_region_fyvs_ahh9': u'25',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'6',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'21769000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'244',
#   u'end_date': u'2019-09-16T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7246825407438',
#   u'limits': u'MISSION ST intersection',
#   u'location': {u'coordinates': [-122.434798, 37.724683], u'type': u'Point'},
#   u'longitude': u'-122.434798413138',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0366_PR_69',
#   u'project_name_full': u'_NA - Mission St Pavement Renovation Phase 1',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2019-01-15T00:00:00.000',
#   u'street_name': u'BRAZIL AVE',
#   u'x': u'6002129.55997',
#   u'y': u'2092119.56779'},
#  {u':@computed_region_bh8s_q3mv': u'64',
#   u':@computed_region_fyvs_ahh9': u'24',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'6',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'11647000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'731',
#   u'end_date': u'2018-12-02T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Microsurfacing',
#   u'group_code': u'2807J',
#   u'latitude': u'37.7161307021847',
#   u'limits': u'BRIGHT ST to HEAD ST (100 - 199)',
#   u'location': {u'coordinates': [-122.463971, 37.716131], u'type': u'Point'},
#   u'longitude': u'-122.463970767323',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0566_PP_32',
#   u'project_name_full': u'2807J - As Needed Pavement Preservation Contract No 1',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Microsurfacing',
#   u'start_date': u'2016-12-01T00:00:00.000',
#   u'street_name': u'SARGENT ST',
#   u'x': u'5993628.90105',
#   u'y': u'2089182.10996'},
#  {u':@computed_region_bh8s_q3mv': u'28856',
#   u':@computed_region_fyvs_ahh9': u'29',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'11004000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'359',
#   u'end_date': u'2017-07-05T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2645J',
#   u'latitude': u'37.7526557331598',
#   u'limits': u'24TH ST to 25TH ST (1300 - 1399)',
#   u'location': {u'coordinates': [-122.401416, 37.752656], u'type': u'Point'},
#   u'longitude': u'-122.401416129464',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0519_PR_12',
#   u'project_name_full': u'2694J - Joint - Sewer Lead - SOMA, Bernal Heights, and Excelsior Districts Pavement Renovation (WW-6',
#   u'project_status': u'Started',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2016-07-11T00:00:00.000',
#   u'street_name': u'RHODE ISLAND ST',
#   u'x': u'6011989.19374',
#   u'y': u'2102105.16699'},
#  {u':@computed_region_bh8s_q3mv': u'58',
#   u':@computed_region_fyvs_ahh9': u'1',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'10974000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'151',
#   u'end_date': u'2019-05-17T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7279553507935',
#   u'limits': u'HAWES ST to INGALLS ST (1200 - 1299)',
#   u'location': {u'coordinates': [-122.383622, 37.727955], u'type': u'Point'},
#   u'longitude': u'-122.383621640181',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0106_PR_24',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 44',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2018-12-17T00:00:00.000',
#   u'street_name': u'REVERE AVE',
#   u'x': u'6016951.66645',
#   u'y': u'2093009.08078'},
#  {u':@computed_region_bh8s_q3mv': u'28859',
#   u':@computed_region_fyvs_ahh9': u'19',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'10673000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'729',
#   u'end_date': u'2016-10-04T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2424J',
#   u'latitude': u'37.7515465421406',
#   u'limits': u'25TH ST to 25TH ST \\ CESAR CHAVEZ ON RAMP (1296 - 1365)',
#   u'location': {u'coordinates': [-122.406203, 37.751547], u'type': u'Point'},
#   u'longitude': u'-122.406202988906',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0312_SW_16',
#   u'project_name_full': u'2470J - 26th-Broderick-Brunswick-Scott Sewer Replacement',
#   u'project_status': u'Started',
#   u'start_date': u'2014-10-06T00:00:00.000',
#   u'street_name': u'POTRERO AVE',
#   u'x': u'6010597.33313',
#   u'y': u'2101729.52367'},
#  {u':@computed_region_bh8s_q3mv': u'63',
#   u':@computed_region_fyvs_ahh9': u'22',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'5',
#   u':@computed_region_yftq_j783': u'2',
#   u'cnn': u'2494000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'180',
#   u'end_date': u'2019-06-13T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7474992772823',
#   u'limits': u'SANCHEZ ST to NOE ST (4000 - 4099)',
#   u'location': {u'coordinates': [-122.430373, 37.747499], u'type': u'Point'},
#   u'longitude': u'-122.430373280622',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0571_PR_28',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 50',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2018-12-15T00:00:00.000',
#   u'street_name': u'CESAR CHAVEZ ST',
#   u'x': u'6003580.46797',
#   u'y': u'2100399.37595'},
#  {u':@computed_region_bh8s_q3mv': u'56',
#   u':@computed_region_fyvs_ahh9': u'12',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'3',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'27365000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Roadway',
#   u'duration': u'537',
#   u'end_date': u'2016-08-15T00:00:00.000',
#   u'facility_type': u'Roadway',
#   u'group_code': u'2419J',
#   u'latitude': u'37.7617471380916',
#   u'limits': u'JUDAH ST intersection',
#   u'location': {u'coordinates': [-122.475924, 37.761747], u'type': u'Point'},
#   u'longitude': u'-122.475924092917',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Mechanical\\Electrical',
#   u'project_id': u'DPW0259_TS_7',
#   u'project_name_full': u'2419J - 2419J Go Bond Traffic Signal Upgrade',
#   u'project_status': u'Started',
#   u'start_date': u'2015-02-25T00:00:00.000',
#   u'street_name': u'18TH AVE',
#   u'x': u'5990522.82996',
#   u'y': u'2105860.99244'},
#  {u':@computed_region_bh8s_q3mv': u'59',
#   u':@computed_region_fyvs_ahh9': u'40',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'4',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'9237000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'365',
#   u'end_date': u'2018-01-02T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2696J',
#   u'latitude': u'37.7278333162216',
#   u'limits': u'END to END (225 - 267)',
#   u'location': {u'coordinates': [-122.468922, 37.727833], u'type': u'Point'},
#   u'longitude': u'-122.468921983371',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0530_PR_28',
#   u'project_name_full': u'2696J - Urbano Dr Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-01-02T00:00:00.000',
#   u'street_name': u'MONCADA WAY',
#   u'x': u'5992286.71833',
#   u'y': u'2093472.38939'},
#  {u':@computed_region_bh8s_q3mv': u'28856',
#   u':@computed_region_fyvs_ahh9': u'29',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'3718000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'184',
#   u'end_date': u'2019-01-01T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7526985417329',
#   u'limits': u'CORAL RD to CAIRE TER (1148 - 1199)',
#   u'location': {u'coordinates': [-122.399407, 37.752699], u'type': u'Point'},
#   u'longitude': u'-122.399407050792',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0621_PR_5',
#   u'project_name_full': u'_NA - Various Locations Concrete Renovation No 2',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2018-07-01T00:00:00.000',
#   u'street_name': u'CAROLINA ST',
#   u'x': u'6012570.23176',
#   u'y': u'2102108.95702'},
#  {u':@computed_region_bh8s_q3mv': u'28862',
#   u':@computed_region_fyvs_ahh9': u'22',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'5',
#   u':@computed_region_yftq_j783': u'2',
#   u'cnn': u'3801000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'185',
#   u'end_date': u'2019-01-02T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2463J',
#   u'latitude': u'37.7508993146591',
#   u'limits': u'24TH ST to JERSEY ST (1300 - 1399)',
#   u'location': {u'coordinates': [-122.434048, 37.750899], u'type': u'Point'},
#   u'longitude': u'-122.434048016142',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0304_PR_14',
#   u'project_name_full': u'2463J - Joint - SFWD Lead - 26th St Pavement Renovation (WD-2739)',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2018-07-01T00:00:00.000',
#   u'street_name': u'CASTRO ST',
#   u'x': u'6002543.8073',
#   u'y': u'2101659.06664'},
#  {u':@computed_region_bh8s_q3mv': u'28859',
#   u':@computed_region_fyvs_ahh9': u'22',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'5',
#   u':@computed_region_yftq_j783': u'2',
#   u'cnn': u'11435000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'The proposed project along Valencia Street (between Cesar Chavez and Mission Streets); Tiffany Ave (29th & Duncan) & along San Jose & Duncan & includes construction of approximately 2,100 SF of stormw',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'312',
#   u'end_date': u'2016-12-16T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'1992J',
#   u'latitude': u'37.7459732654157',
#   u'limits': u'DUNCAN ST to 28TH ST \\ GUERRERO ST (600 - 650)',
#   u'location': {u'coordinates': [-122.421865, 37.745973], u'type': u'Point'},
#   u'longitude': u'-122.421864702234',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0292_SW_2',
#   u'project_name_full': u'1992J - Valencia Street LID',
#   u'project_status': u'Started',
#   u'start_date': u'2016-02-08T00:00:00.000',
#   u'street_name': u'SAN JOSE AVE',
#   u'x': u'6006028.60872',
#   u'y': u'2099793.21418'},
#  {u':@computed_region_bh8s_q3mv': u'29491',
#   u':@computed_region_fyvs_ahh9': u'40',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'4',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'628000',
#   u'create_date': u'2014-09-30T20:14:00.000',
#   u'description_full': u'Track Replacement & Overhead Rehabilitation',
#   u'dpw_project_class': u'Transit',
#   u'duration': u'669',
#   u'end_date': u'2019-05-01T23:59:00.000',
#   u'facility_type': u'Transit',
#   u'facility_type_description': u'/ Replacement',
#   u'latitude': u'37.742311521074',
#   u'limits': u'TARAVAL ST to ULLOA ST (2400 - 2499)',
#   u'location': {u'coordinates': [-122.471291, 37.742312], u'type': u'Point'},
#   u'longitude': u'-122.471291385859',
#   u'modify_date': u'2016-04-19T20:17:00.000',
#   u'owner': u'SF MTA Capital Programs and Construction',
#   u'project_id': u'FG0122_L',
#   u'project_name_full': u'L-Line Transit Improvement Project',
#   u'project_status': u'Planned',
#   u'project_type': u'Replacement',
#   u'start_date': u'2017-07-01T00:00:00.000',
#   u'street_name': u'15TH AVE',
#   u'x': u'5991712.66482',
#   u'y': u'2098757.4299'},
#  {u':@computed_region_bh8s_q3mv': u'28859',
#   u':@computed_region_fyvs_ahh9': u'2',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'7',
#   u':@computed_region_yftq_j783': u'2',
#   u'cnn': u'10339101',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'244',
#   u'end_date': u'2019-10-31T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7480440877165',
#   u'limits': u'HOLLADAY AVE to MONTCALM ST (1 - 47) -- SOUTH --',
#   u'location': {u'coordinates': [-122.405448, 37.748044], u'type': u'Point'},
#   u'longitude': u'-122.405448243477',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0597_PR_19',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 52',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2019-03-01T00:00:00.000',
#   u'street_name': u'PERALTA AVE',
#   u'x': u'6010789.53002',
#   u'y': u'2100450.03219'},
#  {u':@computed_region_bh8s_q3mv': u'28856',
#   u':@computed_region_fyvs_ahh9': u'34',
#   u':@computed_region_p5aj_wyqh': u'2',
#   u':@computed_region_rxqg_mtj9': u'9',
#   u':@computed_region_yftq_j783': u'6',
#   u'cnn': u'23833000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Curb Ramps',
#   u'duration': u'1703',
#   u'end_date': u'2018-02-10T00:00:00.000',
#   u'facility_indicator': u'Sidewalk',
#   u'facility_subindicator': u'Curb Ramp - Disability Access',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Sidewalk / Curb Ramp - Disability Access',
#   u'group_code': u'1424J-7P',
#   u'latitude': u'37.7791322099614',
#   u'limits': u'WELSH ST intersection',
#   u'location': {u'coordinates': [-122.397539, 37.779132], u'type': u'Point'},
#   u'longitude': u'-122.397538906249',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0297_CR_6',
#   u'project_name_full': u'1424J-7P - Central Subway P2-CN1256-STS',
#   u'project_status': u'Started',
#   u'start_date': u'2013-06-13T00:00:00.000',
#   u'street_name': u'04TH ST',
#   u'x': u'6013305.36134',
#   u'y': u'2111721.06733'},
#  {u':@computed_region_bh8s_q3mv': u'28862',
#   u':@computed_region_fyvs_ahh9': u'22',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'5',
#   u':@computed_region_yftq_j783': u'2',
#   u'cnn': u'4212000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'212',
#   u'end_date': u'2017-10-23T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2500J',
#   u'latitude': u'37.7492267781779',
#   u'limits': u'CHURCH ST to SANCHEZ ST (100 - 199)',
#   u'location': {u'coordinates': [-122.428311, 37.749227], u'type': u'Point'},
#   u'longitude': u'-122.428311400926',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0185_PR_9',
#   u'project_name_full': u'2500J - Clayton St, Clipper St, and Portola Dr Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-03-25T00:00:00.000',
#   u'street_name': u'CLIPPER ST',
#   u'x': u'6004189.44922',
#   u'y': u'2101015.97'},
#  {u':@computed_region_bh8s_q3mv': u'58',
#   u':@computed_region_fyvs_ahh9': u'1',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'8698000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Replacing existing sewer with 30-inch diameter sewer.',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'137',
#   u'end_date': u'2017-09-29T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2683J',
#   u'latitude': u'37.7485522684371',
#   u'limits': u'END to END (1400 - 1429)',
#   u'location': {u'coordinates': [-122.393317, 37.748552], u'type': u'Point'},
#   u'longitude': u'-122.393316886664',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0600_SW_10',
#   u'project_name_full': u'2683J - Marin Street Sewer Replacement',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-05-15T00:00:00.000',
#   u'street_name': u'MARIN ST',
#   u'x': u'6014300.0452',
#   u'y': u'2100563.85039'},
#  {u':@computed_region_bh8s_q3mv': u'28860',
#   u':@computed_region_fyvs_ahh9': u'4',
#   u':@computed_region_p5aj_wyqh': u'1',
#   u':@computed_region_rxqg_mtj9': u'10',
#   u':@computed_region_yftq_j783': u'3',
#   u'cnn': u'11553000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'215',
#   u'end_date': u'2019-03-04T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7971903124604',
#   u'limits': u'GOLD ST to PACIFIC AVE (705 - 799)',
#   u'location': {u'coordinates': [-122.401974, 37.79719], u'type': u'Point'},
#   u'longitude': u'-122.401973964872',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0032_PR_57',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 46',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2018-08-01T00:00:00.000',
#   u'street_name': u'SANSOME ST',
#   u'x': u'6012157.49467',
#   u'y': u'2118321.08099'},
#  {u':@computed_region_bh8s_q3mv': u'28859',
#   u':@computed_region_fyvs_ahh9': u'19',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'10674101',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'820',
#   u'end_date': u'2018-01-10T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2127J',
#   u'latitude': u'37.7504533168585',
#   u'limits': u'25TH ST \\ CESAR CHAVEZ ON RAMP to BAY SHORE BLVD OFF RAMP \\ HWY 101 S OFF RAMP (1367 - 1499) -- EAST --',
#   u'location': {u'coordinates': [-122.4058, 37.750453], u'type': u'Point'},
#   u'longitude': u'-122.405800330666',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0193_PR_30',
#   u'project_name_full': u'2184J - Joint - Streetscape Lead - Potrero Ave Pavement Renovation',
#   u'project_status': u'Started',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2015-10-13T00:00:00.000',
#   u'street_name': u'POTRERO AVE',
#   u'x': u'6010705.61681',
#   u'y': u'2101329.17056'},
#  {u':@computed_region_bh8s_q3mv': u'309',
#   u':@computed_region_fyvs_ahh9': u'28',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'7',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'20907000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'320',
#   u'end_date': u'2017-06-17T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2497J',
#   u'latitude': u'37.7319639507568',
#   u'limits': u'MERRILL ST intersection',
#   u'location': {u'coordinates': [-122.409172, 37.731964], u'type': u'Point'},
#   u'longitude': u'-122.409172384683',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0097_PR_23',
#   u'project_name_full': u'2497J - Bowdoin St, Bryant St, and Hale St Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2016-08-01T00:00:00.000',
#   u'street_name': u'HALE ST',
#   u'x': u'6009593.5687',
#   u'y': u'2094618.10965'},
#  {u':@computed_region_bh8s_q3mv': u'58',
#   u':@computed_region_fyvs_ahh9': u'1',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'10218000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'365',
#   u'end_date': u'2018-02-28T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2291J',
#   u'latitude': u'37.7292077724608',
#   u'limits': u'HAWES ST to INGALLS ST (1100 - 1199)',
#   u'location': {u'coordinates': [-122.382498, 37.729208], u'type': u'Point'},
#   u'longitude': u'-122.382497792444',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0117_PR_2',
#   u'project_name_full': u'2461J - Joint - Streetscape Lead - Palou Ave Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-02-28T00:00:00.000',
#   u'street_name': u'PALOU AVE',
#   u'x': u'6017285.79502',
#   u'y': u'2093458.47879'},
#  {u':@computed_region_bh8s_q3mv': u'59',
#   u':@computed_region_fyvs_ahh9': u'40',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'4',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'33007000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'731',
#   u'end_date': u'2018-12-02T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Microsurfacing',
#   u'group_code': u'2807J',
#   u'latitude': u'37.7357076390531',
#   u'limits': u'SANTA PAULA AVE \\ TERRACE WALK intersection',
#   u'location': {u'coordinates': [-122.464204, 37.735708], u'type': u'Point'},
#   u'longitude': u'-122.46420447848',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0566_PP_192',
#   u'project_name_full': u'2807J - As Needed Pavement Preservation Contract No 1',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Microsurfacing',
#   u'start_date': u'2016-12-01T00:00:00.000',
#   u'street_name': u'SAN ANSELMO AVE',
#   u'x': u'5993710.91618',
#   u'y': u'2096310.27749'},
#  {u':@computed_region_bh8s_q3mv': u'28853',
#   u':@computed_region_fyvs_ahh9': u'6',
#   u':@computed_region_p5aj_wyqh': u'2',
#   u':@computed_region_rxqg_mtj9': u'10',
#   u':@computed_region_yftq_j783': u'5',
#   u'cnn': u'24892000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Construction of Union Square/Market Street Station',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'1699',
#   u'end_date': u'2018-02-10T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'1424J-4P',
#   u'latitude': u'37.7857439754126',
#   u'limits': u'ELLIS ST \\ MARKET ST \\ STOCKTON ST intersection',
#   u'location': {u'coordinates': [-122.405831, 37.785744], u'type': u'Point'},
#   u'longitude': u'-122.405831011071',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0284_PR_2',
#   u'project_name_full': u'1424J-4P - Central Subway P2-CN1253-UMS',
#   u'project_status': u'Started',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2013-06-17T00:00:00.000',
#   u'street_name': u'04TH ST',
#   u'x': u'6010958.4179',
#   u'y': u'2114176.74914'},
#  {u':@computed_region_bh8s_q3mv': u'54',
#   u':@computed_region_fyvs_ahh9': u'31',
#   u':@computed_region_p5aj_wyqh': u'6',
#   u':@computed_region_rxqg_mtj9': u'1',
#   u':@computed_region_yftq_j783': u'11',
#   u'cnn': u'3569000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'167',
#   u'end_date': u'2017-11-22T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2300J',
#   u'latitude': u'37.7865163722717',
#   u'limits': u'LOCUST ST to SPRUCE ST (3500 - 3599)',
#   u'location': {u'coordinates': [-122.452582, 37.786516], u'type': u'Point'},
#   u'longitude': u'-122.452581852811',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Construction Management',
#   u'project_id': u'DPW0595_PR_2',
#   u'project_name_full': u'2843J - Joint - Streetscape Lead - California St from Laurel St to Cherry St (2300J)',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-06-08T00:00:00.000',
#   u'street_name': u'CALIFORNIA ST',
#   u'x': u'5997457.11574',
#   u'y': u'2114736.41717'},
#  {u':@computed_region_bh8s_q3mv': u'308',
#   u':@computed_region_fyvs_ahh9': u'4',
#   u':@computed_region_p5aj_wyqh': u'1',
#   u':@computed_region_rxqg_mtj9': u'10',
#   u':@computed_region_yftq_j783': u'3',
#   u'cnn': u'25057000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Streetscape improvements include corner and bus bulb-outs, sidewalk paving, curb ramps, roadway paving, street lights, decorative crosswalks, median landscaping, street trees, raised crosswalk, and be',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'300',
#   u'end_date': u'2017-05-01T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'1075J',
#   u'latitude': u'37.7976275482865',
#   u'limits': u'STOCKTON ST intersection',
#   u'location': {u'coordinates': [-122.408619, 37.797628], u'type': u'Point'},
#   u'longitude': u'-122.408618845521',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0485_PR_5',
#   u'project_name_full': u'1075J - Broadway Streetscape Improvements - Chinatown Phase 4',
#   u'project_status': u'Started',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2016-07-05T00:00:00.000',
#   u'street_name': u'BROADWAY',
#   u'x': u'6010241.20018',
#   u'y': u'2118519.34066'},
#  {u':@computed_region_bh8s_q3mv': u'28857',
#   u':@computed_region_fyvs_ahh9': u'4',
#   u':@computed_region_p5aj_wyqh': u'1',
#   u':@computed_region_rxqg_mtj9': u'10',
#   u':@computed_region_yftq_j783': u'3',
#   u'cnn': u'13387000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'140',
#   u'end_date': u'2019-04-29T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7947842150823',
#   u'limits': u'CLAY ST to WASHINGTON ST (1 - 99)',
#   u'location': {u'coordinates': [-122.405754, 37.794784], u'type': u'Point'},
#   u'longitude': u'-122.405754471876',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0250_PR_46',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 49',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2018-12-10T00:00:00.000',
#   u'street_name': u'WALTER U LUM PL',
#   u'x': u'6011047.55975',
#   u'y': u'2117467.36848'},
#  {u':@computed_region_bh8s_q3mv': u'28858',
#   u':@computed_region_fyvs_ahh9': u'41',
#   u':@computed_region_p5aj_wyqh': u'9',
#   u':@computed_region_rxqg_mtj9': u'11',
#   u':@computed_region_yftq_j783': u'13',
#   u'cnn': u'25213000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'1102',
#   u'end_date': u'2020-11-07T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2684J',
#   u'latitude': u'37.7854822302906',
#   u'limits': u'GEARY BLVD intersection',
#   u'location': {u'coordinates': [-122.423028, 37.785482], u'type': u'Point'},
#   u'longitude': u'-122.423027552656',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0591_SW_19',
#   u'project_name_full': u'2648J - Geary Street Sewer System Improvements (JV w Geary BRT)',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-11-01T00:00:00.000',
#   u'street_name': u'FRANKLIN ST',
#   u'x': u'6005988.04933',
#   u'y': u'2114183.11292'},
#  {u':@computed_region_bh8s_q3mv': u'28853',
#   u':@computed_region_fyvs_ahh9': u'20',
#   u':@computed_region_p5aj_wyqh': u'2',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'8',
#   u'cnn': u'23858000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'1276',
#   u'end_date': u'2022-04-29T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2817J',
#   u'latitude': u'37.7673163499875',
#   u'limits': u'HENRY ADAMS ST \\ KANSAS ST intersection',
#   u'location': {u'coordinates': [-122.40376, 37.767316], u'type': u'Point'},
#   u'longitude': u'-122.403759537166',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0611_SW_148',
#   u'project_name_full': u'2817J - Folsom Area Stormwater Improvement Project',
#   u'project_status': u'Committed',
#   u'start_date': u'2018-10-31T00:00:00.000',
#   u'street_name': u'15TH ST',
#   u'x': u'6011420.4207',
#   u'y': u'2107456.06288'},
#  {u':@computed_region_bh8s_q3mv': u'309',
#   u':@computed_region_fyvs_ahh9': u'39',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'10',
#   u'cnn': u'6677000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'366',
#   u'end_date': u'2018-08-08T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2810J',
#   u'latitude': u'37.717645296089',
#   u'limits': u'GIRARD ST to BRUSSELS ST (100 - 199)',
#   u'location': {u'coordinates': [-122.40111, 37.717645], u'type': u'Point'},
#   u'longitude': u'-122.401110251961',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0573_SW_7',
#   u'project_name_full': u'2810J - Various Locations Sewer Replacement and Pavement Renovation No 5',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-08-07T00:00:00.000',
#   u'street_name': u'HARKNESS AVE',
#   u'x': u'6011818.65991',
#   u'y': u'2089358.0443'},
#  {u':@computed_region_bh8s_q3mv': u'57',
#   u':@computed_region_fyvs_ahh9': u'17',
#   u':@computed_region_p5aj_wyqh': u'9',
#   u':@computed_region_rxqg_mtj9': u'1',
#   u':@computed_region_yftq_j783': u'13',
#   u'cnn': u'3970000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'699',
#   u'end_date': u'2018-12-31T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2612J',
#   u'latitude': u'37.8021764167801',
#   u'limits': u'VAN NESS AVE to FRANKLIN ST (1300 - 1399)',
#   u'location': {u'coordinates': [-122.425554, 37.802176], u'type': u'Point'},
#   u'longitude': u'-122.425554302742',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0168_PR_1',
#   u'project_name_full': u'2498J - Joint - SFMTA Lead - Chestnut St Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-01-31T00:00:00.000',
#   u'street_name': u'CHESTNUT ST',
#   u'x': u'6005383.08557',
#   u'y': u'2120275.56752'},
#  {u':@computed_region_bh8s_q3mv': u'29492',
#   u':@computed_region_fyvs_ahh9': u'41',
#   u':@computed_region_p5aj_wyqh': u'5',
#   u':@computed_region_rxqg_mtj9': u'11',
#   u':@computed_region_yftq_j783': u'15',
#   u'cnn': u'8905000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'609',
#   u'end_date': u'2024-10-24T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7774800152004',
#   u'limits': u'BRODERICK ST to BAKER ST (1700 - 1799)',
#   u'location': {u'coordinates': [-122.440853, 37.77748], u'type': u'Point'},
#   u'longitude': u'-122.440852558848',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0607_PR_25',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 59',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2023-02-23T00:00:00.000',
#   u'street_name': u'MCALLISTER ST',
#   u'x': u'6000777.64102',
#   u'y': u'2111376.2895'},
#  {u':@computed_region_bh8s_q3mv': u'28856',
#   u':@computed_region_fyvs_ahh9': u'6',
#   u':@computed_region_p5aj_wyqh': u'2',
#   u':@computed_region_rxqg_mtj9': u'9',
#   u':@computed_region_yftq_j783': u'6',
#   u'cnn': u'3076000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'246',
#   u'end_date': u'2018-02-02T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2733J',
#   u'latitude': u'37.7805292545499',
#   u'limits': u'JACK LONDON ALY to 03RD ST (350 - 399)',
#   u'location': {u'coordinates': [-122.393744, 37.780529], u'type': u'Point'},
#   u'longitude': u'-122.393743863339',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0624_SW_3',
#   u'project_name_full': u'2876J - Brannan Street Sewer Replacement',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-06-01T00:00:00.000',
#   u'street_name': u'BRANNAN ST',
#   u'x': u'6014412.21704',
#   u'y': u'2112207.4424'},
#  {u':@computed_region_bh8s_q3mv': u'63',
#   u':@computed_region_fyvs_ahh9': u'38',
#   u':@computed_region_p5aj_wyqh': u'5',
#   u':@computed_region_rxqg_mtj9': u'5',
#   u':@computed_region_yftq_j783': u'2',
#   u'cnn': u'3381000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'183',
#   u'end_date': u'2019-10-01T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7548693484497',
#   u'limits': u'GARDENSIDE DR to DIXIE ALY (428 - 450)',
#   u'location': {u'coordinates': [-122.44412, 37.754869], u'type': u'Point'},
#   u'longitude': u'-122.444119954176',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0631_PR_9',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 53',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2019-04-01T00:00:00.000',
#   u'street_name': u'BURNETT AVE',
#   u'x': u'5999662.50989',
#   u'y': u'2103164.65408'},
#  {u':@computed_region_bh8s_q3mv': u'28859',
#   u':@computed_region_fyvs_ahh9': u'2',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'7',
#   u':@computed_region_yftq_j783': u'2',
#   u'cnn': u'21129000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'244',
#   u'end_date': u'2019-10-31T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7456645820626',
#   u'limits': u'PERALTA AVE intersection',
#   u'location': {u'coordinates': [-122.408973, 37.745665], u'type': u'Point'},
#   u'longitude': u'-122.408973292045',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0597_PR_38',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 52',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2019-03-01T00:00:00.000',
#   u'street_name': u'MONTCALM ST',
#   u'x': u'6009752.88511',
#   u'y': u'2099604.55711'},
#  {u':@computed_region_bh8s_q3mv': u'28852',
#   u':@computed_region_fyvs_ahh9': u'36',
#   u':@computed_region_p5aj_wyqh': u'2',
#   u':@computed_region_rxqg_mtj9': u'9',
#   u':@computed_region_yftq_j783': u'7',
#   u'cnn': u'7562000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Pre-Planning for Sewer R&R work FY17-18. Once projects are developed, locations will be moved to new JO',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'595',
#   u'end_date': u'2019-02-18T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'latitude': u'37.7810439480954',
#   u'limits': u'MARKET ST to MCALLISTER ST (0 - 0)',
#   u'location': {u'coordinates': [-122.412005, 37.781044], u'type': u'Point'},
#   u'longitude': u'-122.412004722027',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0225_SW_164',
#   u'project_name_full': u'_NA - Sewer RR_FY17-18 - Planning',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-07-03T00:00:00.000',
#   u'street_name': u'JONES ST',
#   u'x': u'6009139.75015',
#   u'y': u'2112502.11254'},
#  {u':@computed_region_bh8s_q3mv': u'28859',
#   u':@computed_region_fyvs_ahh9': u'19',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'7',
#   u':@computed_region_yftq_j783': u'8',
#   u'cnn': u'24177000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Planning, Design and Construction of curb ramps at various locations throughout the city. Prioritize locations by ADA Transition Plan. Manage Curb Ramp Program and CRIS database.',
#   u'dpw_project_class': u'Curb Ramps',
#   u'duration': u'512',
#   u'end_date': u'2016-12-31T00:00:00.000',
#   u'facility_indicator': u'Sidewalk',
#   u'facility_subindicator': u'Curb Ramp - Disability Access',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Sidewalk / Curb Ramp - Disability Access',
#   u'group_code': u'2748J',
#   u'latitude': u'37.7649564458906',
#   u'limits': u'RONDEL PL intersection',
#   u'location': {u'coordinates': [-122.42124, 37.764956], u'type': u'Point'},
#   u'longitude': u'-122.421239593339',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0586_CR_21',
#   u'project_name_full': u'2748J - Transition Plan Curb Ramps FY 15-16',
#   u'project_status': u'Started',
#   u'start_date': u'2015-08-07T00:00:00.000',
#   u'street_name': u'16TH ST',
#   u'x': u'6006351.20311',
#   u'y': u'2106700.20226'},
#  {u':@computed_region_bh8s_q3mv': u'29491',
#   u':@computed_region_fyvs_ahh9': u'40',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'4',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'12795000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Combined MTA and PUC project on 19th Avenue between Lincoln Way and Junipero Serra Boulevard. Work includes MTA Muni Forward scope (transit bulbs, stop relocation, signal modification and left turn la',
#   u'dpw_project_class': u'StreetScape',
#   u'duration': u'580',
#   u'end_date': u'2018-12-31T00:00:00.000',
#   u'facility_indicator': u'Streetscape-Landscaping',
#   u'facility_type': u'Land',
#   u'facility_type_description': u'Streetscape-Landscaping',
#   u'group_code': u'2652J',
#   u'latitude': u'37.7412104430841',
#   u'limits': u'18TH AVE to 19TH AVE (1700 - 1799)',
#   u'location': {u'coordinates': [-122.475017, 37.74121], u'type': u'Point'},
#   u'longitude': u'-122.475017005644',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0484_SS_97',
#   u'project_name_full': u'2652J - 2652J 19th Avenue Combined City Project',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-05-30T00:00:00.000',
# ...
#   u'x': u'5995523.80781',
#   u'y': u'2103325.66993'},
#  {u':@computed_region_bh8s_q3mv': u'55',
#   u':@computed_region_fyvs_ahh9': u'26',
#   u':@computed_region_p5aj_wyqh': u'6',
#   u':@computed_region_rxqg_mtj9': u'2',
#   u':@computed_region_yftq_j783': u'11',
#   u'cnn': u'27896000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'304',
#   u'end_date': u'2018-01-30T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2708J',
#   u'latitude': u'37.779403411254',
#   u'limits': u'GEARY BLVD intersection',
#   u'location': {u'coordinates': [-122.49973, 37.779403], u'type': u'Point'},
#   u'longitude': u'-122.499730472456',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0518_PR_22',
#   u'project_name_full': u'2708J - Joint - SFWD Lead - Geary Blvd Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-04-01T00:00:00.000',
#   u'street_name': u'39TH AVE',
#   u'x': u'5983779.96635',
#   u'y': u'2112434.70756'},
#  {u':@computed_region_bh8s_q3mv': u'309',
#   u':@computed_region_fyvs_ahh9': u'28',
#   u':@computed_region_p5aj_wyqh': u'3',
#   u':@computed_region_rxqg_mtj9': u'7',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'12356000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'184',
#   u'end_date': u'2019-12-02T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7303098036097',
#   u'limits': u'PRINCETON ST to CAMBRIDGE ST (662 - 799)',
#   u'location': {u'coordinates': [-122.417808, 37.73031], u'type': u'Point'},
#   u'longitude': u'-122.417808283847',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0643_PR_27',
#   u'project_name_full': u'_NA - Various Locations Pavement Renovation No 56',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2019-06-01T00:00:00.000',
#   u'street_name': u'SWEENY ST',
#   u'x': u'6007084.34289',
#   u'y': u'2094066.99029'},
#  {u':@computed_region_bh8s_q3mv': u'28862',
#   u':@computed_region_fyvs_ahh9': u'3',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'5',
#   u':@computed_region_yftq_j783': u'15',
#   u'cnn': u'25819000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'322',
#   u'end_date': u'2017-11-01T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2504J',
#   u'latitude': u'37.7606923048446',
#   u'limits': u'EUREKA ST intersection',
#   u'location': {u'coordinates': [-122.438265, 37.760692], u'type': u'Point'},
#   u'longitude': u'-122.438265381991',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0475_SW_2',
#   u'project_name_full': u'2660J - Eureka, Grandview and Mangels Sewer Replacement',
#   u'project_status': u'Committed',
#   u'start_date': u'2016-12-14T00:00:00.000',
#   u'street_name': u'18TH ST',
#   u'x': u'6001398.61113',
#   u'y': u'2105249.3496'},
#  {u':@computed_region_bh8s_q3mv': u'29491',
#   u':@computed_region_fyvs_ahh9': u'40',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'4',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'27038000',
#   u'create_date': u'2013-03-30T13:36:00.000',
#   u'description_full': u'\u2026',
#   u'dpw_project_class': u'Water',
#   u'duration': u'364',
#   u'end_date': u'2018-04-02T23:59:00.000',
#   u'facility_type': u'Water',
#   u'latitude': u'37.7502736907381',
#   u'limits': u'CASTENADA AVE intersection',
#   u'location': {u'coordinates': [-122.462068, 37.750274], u'type': u'Point'},
#   u'longitude': u'-122.462068487887',
#   u'modify_date': u'2016-06-22T17:34:00.000',
#   u'owner': u'SF PUC Water',
#   u'project_id': u'5043',
#   u'project_name_full': u'WD-2706: 12-inch Ductile Iron Main Replacement on Pacheco Street from 10th Ave to Castenada and Mage',
#   u'project_status': u'Committed',
#   u'start_date': u'2017-04-03T00:00:00.000',
#   u'street_name': u'ALTON AVE',
#   u'x': u'5994439.64268',
#   u'y': u'2101599.9352'},
#  {u':@computed_region_bh8s_q3mv': u'59',
#   u':@computed_region_fyvs_ahh9': u'40',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'4',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'22644000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'322',
#   u'end_date': u'2017-11-01T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2504J',
#   u'latitude': u'37.7326890521038',
#   u'limits': u'VALDEZ AVE intersection',
#   u'location': {u'coordinates': [-122.456077, 37.732689], u'type': u'Point'},
#   u'longitude': u'-122.456076827079',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0253_PR_55',
#   u'project_name_full': u'2504J - Eureka St, Grand View Ave, and Mangels Ave Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2016-12-14T00:00:00.000',
#   u'street_name': u'MANGELS AVE',
#   u'x': u'5996037.7368',
#   u'y': u'2095162.16999'},
#  {u':@computed_region_bh8s_q3mv': u'28858',
#   u':@computed_region_fyvs_ahh9': u'21',
#   u':@computed_region_p5aj_wyqh': u'9',
#   u':@computed_region_rxqg_mtj9': u'10',
#   u':@computed_region_yftq_j783': u'13',
#   u'cnn': u'25222000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'729',
#   u'end_date': u'2018-08-24T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2126J',
#   u'latitude': u'37.7896204239367',
#   u'limits': u'POLK ST intersection',
#   u'location': {u'coordinates': [-122.420493, 37.78962], u'type': u'Point'},
#   u'longitude': u'-122.420493442137',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0114_PR_60',
#   u'project_name_full': u'2064J - Joint - Streetscape Lead - Polk St Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2016-08-25T00:00:00.000',
#   u'street_name': u'PINE ST',
#   u'x': u'6006751.12344',
#   u'y': u'2115674.56641'},
#  {u':@computed_region_bh8s_q3mv': u'28855',
#   u':@computed_region_fyvs_ahh9': u'6',
#   u':@computed_region_p5aj_wyqh': u'2',
#   u':@computed_region_rxqg_mtj9': u'9',
#   u':@computed_region_yftq_j783': u'12',
#   u'cnn': u'24610000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'San Francisco\u2019s vision for a Better Market Street is a comprehensive program to reconstruct the City\u2019s premier cultural, civic and commercial corridor and the region\u2019s most important transit street. P',
#   u'dpw_project_class': u'StreetScape',
#   u'duration': u'730',
#   u'end_date': u'2021-07-30T00:00:00.000',
#   u'facility_indicator': u'Streetscape-Landscaping',
#   u'facility_type': u'Land',
#   u'facility_type_description': u'Streetscape-Landscaping',
#   u'group_code': u'2752J',
#   u'latitude': u'37.7874504850766',
#   u'limits': u'NEW MONTGOMERY ST intersection',
#   u'location': {u'coordinates': [-122.400503, 37.78745], u'type': u'Point'},
#   u'longitude': u'-122.400503096056',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0618_SS_95',
#   u'project_name_full': u'2752J - Better Market Street',
#   u'project_status': u'Committed',
#   u'start_date': u'2019-07-31T00:00:00.000',
#   u'street_name': u'MISSION ST',
#   u'x': u'6012510.37625',
#   u'y': u'2114766.69001'},
#  {u':@computed_region_bh8s_q3mv': u'309',
#   u':@computed_region_fyvs_ahh9': u'39',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'8',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'12259000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'423',
#   u'end_date': u'2018-05-31T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2501J',
#   u'latitude': u'37.7097170632869',
#   u'limits': u'PEABODY ST to RUTLAND ST (600 - 699)',
#   u'location': {u'coordinates': [-122.408186, 37.709717], u'type': u'Point'},
#   u'longitude': u'-122.408186327808',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0186_PR_47',
#   u'project_name_full': u'2501J - University St and Sunnydale Ave Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-04-03T00:00:00.000',
#   u'street_name': u'SUNNYDALE AVE',
#   u'x': u'6009713.5097',
#   u'y': u'2086513.48826'},
#  {u':@computed_region_bh8s_q3mv': u'29492',
#   u':@computed_region_fyvs_ahh9': u'9',
#   u':@computed_region_p5aj_wyqh': u'5',
#   u':@computed_region_rxqg_mtj9': u'11',
#   u':@computed_region_yftq_j783': u'15',
#   u'cnn': u'13369000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'300',
#   u'end_date': u'2017-07-23T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2586J',
#   u'latitude': u'37.7701699901953',
#   u'limits': u'ALPINE TER to BRODERICK ST (850 - 899)',
#   u'location': {u'coordinates': [-122.43816, 37.77017], u'type': u'Point'},
#   u'longitude': u'-122.438159608687',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0132_PR_12',
#   u'project_name_full': u'2499J - Joint - SFWD Lead - Waller St Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2016-09-26T00:00:00.000',
#   u'street_name': u'WALLER ST',
#   u'x': u'6001500.64723',
#   u'y': u'2108698.99695'},
#  {u':@computed_region_bh8s_q3mv': u'29491',
#   u':@computed_region_fyvs_ahh9': u'35',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'3',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'1776000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'479',
#   u'end_date': u'2016-12-22T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Microsurfacing',
#   u'group_code': u'2564J',
#   u'latitude': u'37.750683462653',
#   u'limits': u'ORTEGA ST to PACHECO ST (1900 - 1999)',
#   u'location': {u'coordinates': [-122.493423, 37.750683], u'type': u'Point'},
#   u'longitude': u'-122.493423147906',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0356_PP_551',
#   u'project_name_full': u'2564J - As Needed Pavement Preservation FY 15-16',
#   u'project_status': u'Started',
#   u'project_type': u'Paving-Microsurfacing',
#   u'start_date': u'2015-08-31T00:00:00.000',
#   u'street_name': u'35TH AVE',
#   u'x': u'5985379.66008',
#   u'y': u'2101940.66888'},
#  {u':@computed_region_bh8s_q3mv': u'28861',
#   u':@computed_region_fyvs_ahh9': u'25',
#   u':@computed_region_p5aj_wyqh': u'7',
#   u':@computed_region_rxqg_mtj9': u'6',
#   u':@computed_region_yftq_j783': u'9',
#   u'cnn': u'21736000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'244',
#   u'end_date': u'2019-09-16T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'latitude': u'37.7193093465392',
#   u'limits': u'MISSION ST intersection',
#   u'location': {u'coordinates': [-122.438863, 37.719309], u'type': u'Point'},
#   u'longitude': u'-122.438863485443',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Project Management',
#   u'project_id': u'DPW0366_PR_101',
#   u'project_name_full': u'_NA - Mission St Pavement Renovation Phase 1',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2019-01-15T00:00:00.000',
#   u'street_name': u'KENNY ALY',
#   u'x': u'6000913.59221',
#   u'y': u'2090187.84137'},
#  {u':@computed_region_bh8s_q3mv': u'29490',
#   u':@computed_region_fyvs_ahh9': u'13',
#   u':@computed_region_p5aj_wyqh': u'9',
#   u':@computed_region_rxqg_mtj9': u'11',
#   u':@computed_region_yftq_j783': u'13',
#   u'cnn': u'26594000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Paving',
#   u'duration': u'548',
#   u'end_date': u'2019-02-01T00:00:00.000',
#   u'facility_indicator': u'Roadway Surface',
#   u'facility_type': u'Roadway',
#   u'facility_type_description': u'Roadway Surface / Paving-Roads Only',
#   u'group_code': u'2687J',
#   u'latitude': u'37.7841518498928',
#   u'limits': u'STEINER ST intersection',
#   u'location': {u'coordinates': [-122.434562, 37.784152], u'type': u'Point'},
#   u'longitude': u'-122.434562099023',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Streets & Highways',
#   u'project_id': u'DPW0520_PR_24',
#   u'project_name_full': u'2687J - Joint - SFMTA Lead - Geary Blvd Pavement Renovation',
#   u'project_status': u'Committed',
#   u'project_type': u'Paving-Roads Only',
#   u'start_date': u'2017-08-02T00:00:00.000',
#   u'street_name': u'GEARY BLVD',
#   u'x': u'6002645.48367',
#   u'y': u'2113767.48974'},
#  {u':@computed_region_bh8s_q3mv': u'56',
#   u':@computed_region_fyvs_ahh9': u'12',
#   u':@computed_region_p5aj_wyqh': u'8',
#   u':@computed_region_rxqg_mtj9': u'3',
#   u':@computed_region_yftq_j783': u'1',
#   u'cnn': u'27371000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'description_full': u'Replace structurally inadequate sewers on Irving Street.',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'730',
#   u'end_date': u'2018-10-27T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2541J',
#   u'latitude': u'37.7636087476403',
#   u'limits': u'IRVING ST intersection',
#   u'location': {u'coordinates': [-122.476054, 37.763609], u'type': u'Point'},
#   u'longitude': u'-122.476054379033',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0373_SW_24',
#   u'project_name_full': u'2549J - Irving Street Sewer Replacement Ph II',
#   u'project_status': u'Committed',
#   u'start_date': u'2016-10-27T00:00:00.000',
#   u'street_name': u'18TH AVE',
#   u'x': u'5990499.48791',
#   u'y': u'2106539.48657'},
#  {u':@computed_region_bh8s_q3mv': u'28853',
#   u':@computed_region_fyvs_ahh9': u'19',
#   u':@computed_region_p5aj_wyqh': u'4',
#   u':@computed_region_rxqg_mtj9': u'7',
#   u':@computed_region_yftq_j783': u'8',
#   u'cnn': u'24339000',
#   u'create_date': u'2016-07-24T04:15:08.000',
#   u'dpw_project_class': u'Sewer',
#   u'duration': u'1276',
#   u'end_date': u'2022-04-29T00:00:00.000',
#   u'facility_type': u'Sanitary Sewer',
#   u'group_code': u'2817J',
#   u'latitude': u'37.7684713552497',
#   u'limits': u'SHOTWELL ST intersection',
#   u'location': {u'coordinates': [-122.416707, 37.768471], u'type': u'Point'},
#   u'longitude': u'-122.416707368846',
#   u'modify_date': u'2016-07-24T04:15:08.000',
#   u'owner': u'SF DPW IDC - Hydraulic',
#   u'project_id': u'DPW0611_SW_212',
#   u'project_name_full': u'2817J - Folsom Area Stormwater Improvement Project',
#   u'project_status': u'Committed',
#   u'start_date': u'2018-10-31T00:00:00.000',
#   u'street_name': u'14TH ST',
#   u'x': u'6007687.22542',
#   u'y': u'2107952.92349'},
#  ...]

# %% [markdown]
# Load into a Pandas dataframe, df_util:

# %%
df_util = pd.DataFrame.from_dict(response_dict_util)

# %% [markdown]
# Look at the new dataframe:

# %%
df_util.head()
# Out:
#   :@computed_region_bh8s_q3mv :@computed_region_fyvs_ahh9  \
# 0                          57                          17
# 1                         309                          39
# 2                       29491                          35
# 3                       29491                          40
# 4                          58                           1
#
#   :@computed_region_p5aj_wyqh :@computed_region_rxqg_mtj9  \
# 0                           9                           1
# 1                           7                           8
# 2                           8                           3
# 3                           8                           4
# 4                           3                           8
#
#   :@computed_region_yftq_j783       cnn              create_date  \
# 0                          13   8455201  2016-07-24T04:15:08.000
# 1                           9  20334000  2016-07-24T04:15:08.000
# 2                           1  23276000  2016-02-10T19:40:00.000
# 3                           1  22982000  2016-07-24T04:15:08.000
# 4                          10   7235000  2016-07-24T04:15:08.000
#
#                                     description_full dpw_project_class  \
# 0                                                NaN       StreetScape
# 1  Pre-Planning for Sewer R&R work FY18-19. Once ...             Sewer
# 2                                                NaN               Gas
# 3                                                NaN             Sewer
# 4                                                NaN            Paving
#
#   duration      ...                    modify_date  \
# 0      540      ...        2016-07-24T04:15:08.000
# 1      595      ...        2016-07-24T04:15:08.000
# 2       90      ...        2016-06-07T01:33:00.000
# 3      489      ...        2016-07-24T04:15:08.000
# 4      239      ...        2016-07-24T04:15:08.000
#
#                              owner      project_id  \
# 0  SF DPW IDC - Streets & Highways    DPW0503_SS_6
# 1           SF DPW IDC - Hydraulic  DPW0028_SW_262
# 2                             PG&E        31217760
# 3           SF DPW IDC - Hydraulic   DPW0272_SW_13
# 4  SF DPW IDC - Streets & Highways   DPW0160_PR_38
#
#                                    project_name_full project_status  \
# 0     2532J - Lombard Street Pedestrian Improvements      Committed
# 1                  _NA - Sewer RR_FY18-19 - Planning      Committed
# 2                                      Replace V8006        Started
# 3  2422J - West Portal Avenue and Quintara Street...        Started
# 4  2493J - Ingalls St and Industrial St Pavement ...        Started
#
#         project_type               start_date street_name              x  \
# 0                NaN  2017-08-31T00:00:00.000  LOMBARD ST  6004477.09597
# 1                NaN  2018-07-02T00:00:00.000  RUTLAND ST  6010509.80218
# 2                NaN  2016-05-01T00:00:00.000    27TH AVE   5987965.3937
# 3                NaN  2015-04-06T00:00:00.000    10TH AVE  5993196.81375
# 4  Paving-Roads Only  2016-04-04T00:00:00.000  INGALLS ST  6015264.15124
#
#                y
# 0  2119809.33857
# 1  2089001.06706
# 2  2098968.32098
# 3  2101189.32149
# 4  2091299.04641
#
# [5 rows x 30 columns]

# %% [markdown]
# Key fields:
# create_date
# description_full (incomplete data)
# **dwp_project_class(StreetScape, Sewer, Gas, Paving, ...)**
# owner (PG&E, SF DPW IDC - Hydraulic, SF DPW IDC - Streets & Highways, ...)
# project_id
# project_name_full
# **project_status (Started, Committed, Planned, ...)**
# **start_date**
# street_name
# **latitude**
# **longitude**
# ? x
# ? y

# %%
url = ('https://data.sfgov.org/resource/vad7-rtjc.json')
    
r = requests.get(url)
response_dict = json.loads(r.text)
